# %%
import pandas as pd
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
from IPython.display import clear_output
from sklearn.metrics import roc_auc_score

# %%
with open('trainoldYoungALLDEment.txt', 'r', encoding='utf-8-sig') as fin:
    with open('train.txt', 'w', encoding='utf-8-sig') as fout:
        for line in fin.readlines():
            fout.write(line.replace(',', '.'))

# %%
data = pd.read_csv('train.txt', sep='\t')

features = data.columns.values[2:]
target = np.array(list(set(data['cl'])))

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url="https://bstudy.net/htm/img/3/10226/19.png", width=500, height=500)
# Out:
# <img src="https://bstudy.net/htm/img/3/10226/19.png" width="500" height="500"/>

# %%
print('features:', len(features))
print(features)
# Out:
# features: 256
# ['channel=Fp1_1' 'channel=Fp1_2' 'channel=Fp1_3' 'channel=Fp1_4'
#  'channel=Fp1_5' 'channel=Fp1_6' 'channel=Fp1_7' 'channel=Fp1_8'
#  'channel=Fp1_9' 'channel=Fp1_10' 'channel=Fp1_11' 'channel=Fp1_12'
#  'channel=Fp1_13' 'channel=Fp1_14' 'channel=Fp1_15' 'channel=Fp1_16'
#  'channel=Fp2_1' 'channel=Fp2_2' 'channel=Fp2_3' 'channel=Fp2_4'
#  'channel=Fp2_5' 'channel=Fp2_6' 'channel=Fp2_7' 'channel=Fp2_8'
#  'channel=Fp2_9' 'channel=Fp2_10' 'channel=Fp2_11' 'channel=Fp2_12'
#  'channel=Fp2_13' 'channel=Fp2_14' 'channel=Fp2_15' 'channel=Fp2_16'
#  'channel=F33_1' 'channel=F33_2' 'channel=F33_3' 'channel=F33_4'
#  'channel=F33_5' 'channel=F33_6' 'channel=F33_7' 'channel=F33_8'
#  'channel=F33_9' 'channel=F33_10' 'channel=F33_11' 'channel=F33_12'
#  'channel=F33_13' 'channel=F33_14' 'channel=F33_15' 'channel=F33_16'
#  'channel=F4_1' 'channel=F4_2' 'channel=F4_3' 'channel=F4_4'
#  'channel=F4_5' 'channel=F4_6' 'channel=F4_7' 'channel=F4_8'
#  'channel=F4_9' 'channel=F4_10' 'channel=F4_11' 'channel=F4_12'
#  'channel=F4_13' 'channel=F4_14' 'channel=F4_15' 'channel=F4_16'
#  'channel=C3_1' 'channel=C3_2' 'channel=C3_3' 'channel=C3_4'
#  'channel=C3_5' 'channel=C3_6' 'channel=C3_7' 'channel=C3_8'
#  'channel=C3_9' 'channel=C3_10' 'channel=C3_11' 'channel=C3_12'
#  'channel=C3_13' 'channel=C3_14' 'channel=C3_15' 'channel=C3_16'
#  'channel=C4_1' 'channel=C4_2' 'channel=C4_3' 'channel=C4_4'
#  'channel=C4_5' 'channel=C4_6' 'channel=C4_7' 'channel=C4_8'
#  'channel=C4_9' 'channel=C4_10' 'channel=C4_11' 'channel=C4_12'
#  'channel=C4_13' 'channel=C4_14' 'channel=C4_15' 'channel=C4_16'
#  'channel=P3_1' 'channel=P3_2' 'channel=P3_3' 'channel=P3_4'
#  'channel=P3_5' 'channel=P3_6' 'channel=P3_7' 'channel=P3_8'
#  'channel=P3_9' 'channel=P3_10' 'channel=P3_11' 'channel=P3_12'
#  'channel=P3_13' 'channel=P3_14' 'channel=P3_15' 'channel=P3_16'
#  'channel=P4_1' 'channel=P4_2' 'channel=P4_3' 'channel=P4_4'
#  'channel=P4_5' 'channel=P4_6' 'channel=P4_7' 'channel=P4_8'
#  'channel=P4_9' 'channel=P4_10' 'channel=P4_11' 'channel=P4_12'
#  'channel=P4_13' 'channel=P4_14' 'channel=P4_15' 'channel=P4_16'
#  'channel=O1_1' 'channel=O1_2' 'channel=O1_3' 'channel=O1_4'
#  'channel=O1_5' 'channel=O1_6' 'channel=O1_7' 'channel=O1_8'
#  'channel=O1_9' 'channel=O1_10' 'channel=O1_11' 'channel=O1_12'
#  'channel=O1_13' 'channel=O1_14' 'channel=O1_15' 'channel=O1_16'
#  'channel=O2_1' 'channel=O2_2' 'channel=O2_3' 'channel=O2_4'
#  'channel=O2_5' 'channel=O2_6' 'channel=O2_7' 'channel=O2_8'
#  'channel=O2_9' 'channel=O2_10' 'channel=O2_11' 'channel=O2_12'
#  'channel=O2_13' 'channel=O2_14' 'channel=O2_15' 'channel=O2_16'
#  'channel=F7_1' 'channel=F7_2' 'channel=F7_3' 'channel=F7_4'
#  'channel=F7_5' 'channel=F7_6' 'channel=F7_7' 'channel=F7_8'
#  'channel=F7_9' 'channel=F7_10' 'channel=F7_11' 'channel=F7_12'
#  'channel=F7_13' 'channel=F7_14' 'channel=F7_15' 'channel=F7_16'
#  'channel=F8_1' 'channel=F8_2' 'channel=F8_3' 'channel=F8_4'
#  'channel=F8_5' 'channel=F8_6' 'channel=F8_7' 'channel=F8_8'
#  'channel=F8_9' 'channel=F8_10' 'channel=F8_11' 'channel=F8_12'
#  'channel=F8_13' 'channel=F8_14' 'channel=F8_15' 'channel=F8_16'
#  'channel=T3_1' 'channel=T3_2' 'channel=T3_3' 'channel=T3_4'
#  'channel=T3_5' 'channel=T3_6' 'channel=T3_7' 'channel=T3_8'
#  'channel=T3_9' 'channel=T3_10' 'channel=T3_11' 'channel=T3_12'
#  'channel=T3_13' 'channel=T3_14' 'channel=T3_15' 'channel=T3_16'
#  'channel=T4_1' 'channel=T4_2' 'channel=T4_3' 'channel=T4_4'
#  'channel=T4_5' 'channel=T4_6' 'channel=T4_7' 'channel=T4_8'
#  'channel=T4_9' 'channel=T4_10' 'channel=T4_11' 'channel=T4_12'
#  'channel=T4_13' 'channel=T4_14' 'channel=T4_15' 'channel=T4_16'
#  'channel=T5_1' 'channel=T5_2' 'channel=T5_3' 'channel=T5_4'
#  'channel=T5_5' 'channel=T5_6' 'channel=T5_7' 'channel=T5_8'
#  'channel=T5_9' 'channel=T5_10' 'channel=T5_11' 'channel=T5_12'
#  'channel=T5_13' 'channel=T5_14' 'channel=T5_15' 'channel=T5_16'
#  'channel=T6_1' 'channel=T6_2' 'channel=T6_3' 'channel=T6_4'
#  'channel=T6_5' 'channel=T6_6' 'channel=T6_7' 'channel=T6_8'
#  'channel=T6_9' 'channel=T6_10' 'channel=T6_11' 'channel=T6_12'
#  'channel=T6_13' 'channel=T6_14' 'channel=T6_15' 'channel=T6_16']

# %%
print('target:', *target)
# Out:
# target: 1 2

# %%
print('1:', np.sum(data['cl'] == 1))
print('2:', np.sum(data['cl'] == 2))
# Out:
# 1: 50
# 2: 34

# %%
fig, axs = plt.subplots(1, 2)

axs[0].plot(data['channel=F4_16'])
axs[0].set_title('F4_16')

axs[1].plot(data['channel=Fp1_5'])
axs[1].set_title('Fp1_5')

plt.show()

# %%
fig, axs = plt.subplots(1, 2)

axs[0].plot(data['channel=P4_5'])
axs[0].set_title('P4_5')

axs[1].plot(data['channel=C3_8'])
axs[1].set_title('C3_8')

plt.show()

# %%
fig, axs = plt.subplots(1, 2)

axs[0].plot(data['channel=F33_3'])
axs[0].set_title('F33_3')

axs[1].plot(data['channel=T4_6'])
axs[1].set_title('T4_6')

plt.show()

# %%
fig, axs = plt.subplots(1, 2)

axs[0].plot(data['channel=F33_3'])
axs[0].set_title('F33_3')

axs[1].plot(data['channel=T4_6'])
axs[1].set_title('T4_6')

plt.show()

# %%
x_data = data.values[:, 2:].astype(np.float32)
y_data = data.values[:, 1].astype(np.int64) - 1

size = x_data.shape[1]
size
# Out:
# 256

# %% [markdown]
# В силу отсутсвия большого количества прецедентов буду обучать модель при помощи StratifiedKFold.
#
# Оптимизация: Adadelta.

# %%
def train(network, epochs, learning_rate, n_sp, opt='adadelta'):
    loss = nn.NLLLoss()
    skf = StratifiedKFold(n_splits=n_sp, shuffle=True)
    if opt == 'adam':
        optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
    elif opt == 'adadelta':
        optimizer = torch.optim.Adadelta(network.parameters(), lr=learning_rate)
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in range(epochs + 1):
            losses = []
            accuracies = []
            for train_index, test_index in skf.split(x_data, y_data):
                X_train, X_test = x_data[train_index], x_data[test_index]
                y_train, y_test = y_data[train_index], y_data[test_index]

                train_loader = DataLoader([(X_train[i], y_train[i])
                                         for i in range(y_train.shape[0])],
                                        batch_size=10, shuffle=True)
                test_loader = DataLoader([(X_test[i], y_test[i])
                                        for i in range(y_test.shape[0])],
                                       batch_size=10, shuffle=False)

                for X, y in train_loader:
                    network.zero_grad()
                    prediction = network(X)
                    loss_batch = loss(prediction, y)
                    losses.append(loss_batch.item())
                    loss_batch.backward()
                    optimizer.step()
                    accuracies.append((np.argmax(prediction.data.numpy(), 1)==y.data.numpy()).mean())

                train_loss_epochs.append(np.mean(losses))
                train_accuracy_epochs.append(np.mean(accuracies))
                losses = []
                accuracies = []
                
                for X, y in test_loader:
                    prediction = network(X)
                    loss_batch = loss(prediction, y)
                    losses.append(loss_batch.item())
                    accuracies.append((np.argmax(prediction.data.numpy(), 1)==y.data.numpy()).mean())
                test_loss_epochs.append(np.mean(losses))
                test_accuracy_epochs.append(np.mean(accuracies))
                
            if epoch % 50 == 0:
                clear_output(True)
                print('\rEpoch {0}... (Train/Test) NLL: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
                plt.figure(figsize=(12, 5))
                plt.plot(train_loss_epochs, label='Train')
                plt.plot(test_loss_epochs, label='Test')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Loss', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid()
                plt.show()
    except KeyboardInterrupt:
        pass

# %%
class LinClassifier(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.linear = nn.Sequential(nn.Linear(size, size // 2),
                                    nn.ReLU(),
                                    nn.Linear(size // 2, size // 4),
                                    nn.ReLU(),
                                    nn.Linear(size // 4, size // 8),
                                    nn.ReLU(),
                                    nn.Linear(size // 8, size // 16),
                                    nn.ReLU(),
                                    nn.Linear(size // 16, len(target)),
                                    nn.LogSoftmax(dim=1))
    
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

# %% [markdown]
# Обучим модель:

# %%
network = LinClassifier(size)
train(network, 300, 0.006, 5, 'adadelta')
# Out:
# Epoch 300... (Train/Test) NLL: 0.616/0.556	Accuracy: 0.674/0.783

# %% [markdown]
# Оценка ROC AUC:

# %%
roc_auc_score(np.argmax(network.forward(torch.Tensor(x_data)).data.numpy(), 1),
              y_data)
# Out:
# 0.8290441176470589

# %% [markdown]
# Попробуем предобработать данные, центрировав их.

# %%
x_data -= np.mean(x_data, 1).reshape(-1, 1)

# %% [markdown]
# Оптимизатор: Adam.

# %%
network = LinClassifier(size)
train(network, 200, 0.00005, 5, 'adam')
# Out:
# Epoch 200... (Train/Test) NLL: 0.057/0.064	Accuracy: 0.961/1.000

# %% [markdown]
# Оценка ROC AUC:

# %%
roc_auc_score(np.argmax(network.forward(torch.Tensor(x_data)).data.numpy(), 1),
              y_data)
# Out:
# 0.9807692307692308
